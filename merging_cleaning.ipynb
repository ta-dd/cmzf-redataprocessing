# %%
import pandas as pd
import requests
import numpy as np

# %%
file_name="df_garages_2022-12-22.gzip"

# %%
file_name_desc=(file_name[:-5]+"_desc.gzip")
df=pd.read_parquet(file_name)
df_desc=pd.read_parquet(file_name_desc)

# %%
df.head()
# Out:
#       hash_id      price  price_czk  area        lat        lon  \
# 0  2670483276  1225000.0  1225000.0  21.0  50.035338  14.458362
# 1  2495821644  1758000.0  1758000.0  21.0  50.057895  14.518219
# 2   156955724     2000.0     2000.0  13.0  50.064158  14.500559
# 3  2362082380   558000.0   558000.0  17.0  49.997397  14.413837
# 4   377640780   395000.0   395000.0  16.0  50.100554  14.498755
#
#                locality  type  category  is_auction  exclusively_at_rk  \
# 0      Praha 4 - Michle     1         5       False                  0
# 1  Praha 10 - Strašnice     1         5       False                  1
# 2  Praha 10 - Strašnice     2         5       False                  1
# 3     Praha 4 - Modřany     1         5       False                  0
# 4      Praha 9 - Prosek     1         5       False                  1
#
#    category_main_cb  category_sub_cb  category_type_cb  company_id  \
# 0                 5               52                 1     43314.0
# 1                 5               34                 1         NaN
# 2                 5               34                 2         NaN
# 3                 5               34                 1         NaN
# 4                 5               52                 1     14367.0
#
#        company_name
# 0        Duna House
# 1              None
# 2              None
# 3              None
# 4  Home Real Estate

# %%
df_desc.head()
# Out:
#                                                   description discounted  \
# 2670483276  Prodávám garážové stání v osobním vlastnictví ...       None
# 2495821644  Nabízím k prodeji zděnou garáž o velikosti 16 ...       None
# 156955724   Nabízíme garážové stání k pronájmu ve druhém p...       None
# 2362082380  Nabízíme k prodeji parkovací stání o rozměrech...       None
# 377640780   Společnost Home Real Estate nabízí na prodej v...       None
#
#            price_original  id_order date_update building_type  \
# 2670483276           None  GR145386       Včera       Cihlová
# 2495821644           None  14425911       Včera       Cihlová
# 156955724            None      0384       Včera       Cihlová
# 2362082380           None     PS.22       Včera       Smíšená
# 377640780            None     36008       Včera       Cihlová
#
#            building_condition building_location area_net area_floor  ...  \
# 2670483276        Velmi dobrý  Klidná část obce       19         19  ...
# 2495821644              Dobrý              None       19       None  ...
# 156955724         Velmi dobrý      Centrum obce       12       None  ...
# 2362082380         Novostavba  Klidná část obce       15       None  ...
# 377640780         Velmi dobrý              None       14       None  ...
#
#            heating telecommunication date_year_reconstruction  \
# 2670483276    None              None                      NaN
# 2495821644    None              None                      NaN
# 156955724     None              None                      NaN
# 2362082380    None              None                      NaN
# 377640780     None              None                      NaN
#
#            energy_efficient_rating_card availability  date_offer_start  \
# 2670483276                         None         None              None
# 2495821644                         None         None              None
# 156955724                          None         None              None
# 2362082380                         None         None              None
# 377640780                          None         None              None
#
#            energy_efficient_rating_index date_tour date_tour_to area_garden
# 2670483276                          None      None         None        None
# 2495821644                          None      None         None        None
# 156955724                           None      None         None        None
# 2362082380                          None      None         None        None
# 377640780                           None      None         None        None
#
# [5 rows x 38 columns]
